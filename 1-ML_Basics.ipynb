# %% [markdown]
# <a href="https://colab.research.google.com/github/mdirfan5/machine-learning/blob/main/1-ML_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![1.1 AI vs Machine Learning vs Deep Learning _ AI vs ML vs DL _ Machine Learning Training with Python - YouTube - Google Chrome 17-12-2021 07_34_57 (2).png](data:image/png;base64,...)

# %% [markdown]
# ### **Relationship between These Terms-**
#
# Artificial Intelligence is a broader field and Machine Learning is a subset of artificial intelligence and again deep learning is a further subset of Machine learning.
